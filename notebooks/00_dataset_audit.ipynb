# %%
import sys
import os

root_path = os.path.abspath(os.path.join('..'))

if root_path not in sys.path:
    sys.path.append(root_path)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
raw = pd.read_csv('..\\data\\raw\\games.csv', index_col= False)
raw.head()
# Out:
#      AppID                                   Name  Release date  \
# 0  2539430             Black Dragon Mage Playtest   Aug 1, 2023
# 1   496350  Supipara - Chapter 1 Spring Has Come!  Jul 29, 2016
# 2  1034400      Mystery Solitaire The Black Raven   May 6, 2019
# 3  3292190            버튜버 파라노이아 - Vtuber Paranoia  Oct 31, 2024
# 4  3631080                          Maze Quest VR  Apr 24, 2025
#
#   Estimated owners  Peak CCU  Required age  Price  DiscountDLC count  \
# 0            0 - 0         0             0   0.00                  0
# 1        0 - 20000         0             0   5.24                 65
# 2        0 - 20000         0             0   4.99                  0
# 3        0 - 20000         1             0   8.99                  0
# 4        0 - 20000         0             0   4.99                  0
#
#    About the game                                Supported languages  ...  \
# 0               0                                                NaN  ...
# ...

# %%
raw.shape
# Out:
# (122611, 39)

# %%
raw.columns
# Out:
# Index(['AppID', 'Name', 'Release date', 'Estimated owners', 'Peak CCU',
#        'Required age', 'Price', 'DiscountDLC count', 'About the game',
#        'Supported languages', 'Full audio languages', 'Reviews',
#        'Header image', 'Website', 'Support url', 'Support email', 'Windows',
#        'Mac', 'Linux', 'Metacritic score', 'Metacritic url', 'User score',
#        'Positive', 'Negative', 'Score rank', 'Achievements', 'Recommendations',
#        'Notes', 'Average playtime forever', 'Average playtime two weeks',
#        'Median playtime forever', 'Median playtime two weeks', 'Developers',
#        'Publishers', 'Categories', 'Genres', 'Tags', 'Screenshots', 'Movies'],
#       dtype='str')

# %%
raw.iloc[0]
# Out:
# AppID                                                                   2539430
# Name                                                 Black Dragon Mage Playtest
# Release date                                                        Aug 1, 2023
# Estimated owners                                                          0 - 0
# Peak CCU                                                                      0
# Required age                                                                  0
# Price                                                                       0.0
# DiscountDLC count                                                             0
# About the game                                                                0
# Supported languages                                                         NaN
# Full audio languages                                                         []
# Reviews                                                                      []
# ...

# %%
raw.iloc[0].to_dict()
# Out:
# {'AppID': 2539430,
#  'Name': 'Black Dragon Mage Playtest',
#  'Release date': 'Aug 1, 2023',
#  'Estimated owners': '0 - 0',
#  'Peak CCU': 0,
#  'Required age': 0,
#  'Price': 0.0,
#  'DiscountDLC count': 0,
#  'About the game': 0,
#  'Supported languages': nan,
#  'Full audio languages': '[]',
#  'Reviews': '[]',
#  'Header image': nan,
#  'Website': 'https://shared.akamai.steamstatic.com/store_item_assets/steam/apps/2539430/header.jpg?t=1699268702',
#  'Support url': nan,
#  'Support email': nan,
#  'Windows': nan,
#  'Mac': True,
#  'Linux': False,
#  'Metacritic score': False,
#  'Metacritic url': 0,
#  'User score': nan,
#  'Positive': 0,
#  'Negative': 0,
#  'Score rank': 0,
#  'Achievements': nan,
#  'Recommendations': 0,
#  'Notes': 0,
#  'Average playtime forever': nan,
#  'Average playtime two weeks': 0,
#  'Median playtime forever': 0,
#  'Median playtime two weeks': 0,
#  'Developers': 0,
#  'Publishers': nan,
#  'Categories': nan,
#  'Genres': nan,
#  'Tags': nan,
# ...

# %%
print(raw.columns.shape)
print(len(raw.columns))
# Out:
# (39,)
# 39

# %%
raw.loc[1].to_dict()
# Out:
# {'AppID': 496350,
#  'Name': 'Supipara - Chapter 1 Spring Has Come!',
#  'Release date': 'Jul 29, 2016',
#  'Estimated owners': '0 - 20000',
#  'Peak CCU': 0,
#  'Required age': 0,
#  'Price': 5.24,
#  'DiscountDLC count': 65,
#  'About the game': 0,
# ...

# %%
raw.columns.tolist()
# Out:
# ['AppID',
#  'Name',
#  'Release date',
#  'Estimated owners',
#  'Peak CCU',
#  'Required age',
#  'Price',
#  'DiscountDLC count',
#  'About the game',
#  'Supported languages',
#  'Full audio languages',
#  'Reviews',
#  'Header image',
#  'Website',
#  'Support url',
#  'Support email',
#  'Windows',
#  'Mac',
#  'Linux',
#  'Metacritic score',
#  'Metacritic url',
#  'User score',
#  'Positive',
#  'Negative',
#  'Score rank',
#  'Achievements',
#  'Recommendations',
#  'Notes',
#  'Average playtime forever',
#  'Average playtime two weeks',
#  'Median playtime forever',
#  'Median playtime two weeks',
#  'Developers',
#  'Publishers',
#  'Categories',
#  'Genres',
#  'Tags',
#  'Screenshots',
#  'Movies']

# %%
with open('../data/raw/games.csv', 'r', encoding='utf-8', errors='ignore') as f:
    for _ in range(3):
        print(f.readline())
# Out:
# AppID,Name,Release date,Estimated owners,Peak CCU,Required age,Price,DiscountDLC count,About the game,Supported languages,Full audio languages,Reviews,Header image,Website,Support url,Support email,Windows,Mac,Linux,Metacritic score,Metacritic url,User score,Positive,Negative,Score rank,Achievements,Recommendations,Notes,Average playtime forever,Average playtime two weeks,Median playtime forever,Median playtime two weeks,Developers,Publishers,Categories,Genres,Tags,Screenshots,Movies
#
# ...

# %%
raw[['About the game',
     'Supported languages',
     'Full audio languages']].head(10)
# Out:
#    About the game                                Supported languages  \
# 0               0                                                NaN
# 1               0  Springtime, April: when the cherry trees come ...
# 2               0  Immerse yourself in the most beloved, mystical...
# 3               1  synopsis 'Hello, I'm Hiyoro, a new YouTuber!' ...
# 4               0  Its not just a Maze; its a Quest! Enter the ca...
# 5               0  A JOURNEY THROUGH HELL! Explore the most terri...
# 6               1  Building on the success of its acclaimed prede...
# 7               0  Years ago, Ricardo Luger was in the wrong plac...
# 8               0  Hepta Beats is a 2D side-view platformer game ...
# 9               1  WARRNING Don't show Your mom this game. You kn...
#
#                                 Full audio languages
# 0                                                 []
# 1                                        ['English']
# ...

# %%
raw['About the game'].value_counts(dropna=False).head(20)
# Out:
# About the game
# 0     104840
# 1      11299
# 2       2831
# 3       1154
# 4        601
# 5        388
# 6        241
# 7        179
# 8        162
# 10       109
# 9        109
# 11        63
# 12        53
# 13        45
# 15        34
# 16        33
# 14        33
# 17        30
# 18        24
# 22        23
# Name: count, dtype: int64

# %%
raw[['About the game',
     'Supported languages',
     'Full audio languages',
     'Reviews']].head(5)
# Out:
#    About the game                                Supported languages  \
# 0               0                                                NaN
# 1               0  Springtime, April: when the cherry trees come ...
# 2               0  Immerse yourself in the most beloved, mystical...
# 3               1  synopsis 'Hello, I'm Hiyoro, a new YouTuber!' ...
# 4               0  Its not just a Maze; its a Quest! Enter the ca...
#
#                          Full audio languages      Reviews
# 0                                          []           []
# 1                                 ['English']           []
# 2  ['English', 'French', 'German', 'Russian']           []
# 3                                  ['Korean']   ['Korean']
# 4                                 ['English']  ['English']

# %%
#csv shows mistakes, changing it to the original json

# %%
raw_json = pd.read_json('..\\data\\raw\\games.json').T
# Out:
#           index                                   name  release_date  \
# 0       2539430             Black Dragon Mage Playtest   Aug 1, 2023
# 1        496350  Supipara - Chapter 1 Spring Has Come!  Jul 29, 2016
# 2       1034400      Mystery Solitaire The Black Raven   May 6, 2019
# 3       3292190            버튜버 파라노이아 - Vtuber Paranoia  Oct 31, 2024
# 4       3631080                          Maze Quest VR  Apr 24, 2025
# ...         ...                                    ...           ...
# 122606  4152910                                   完美传奇   Jan 4, 2026
# 122607  4042800         Poker Fate - ACG Texas Hold'em   Jan 3, 2026
# 122608  3522550                        Adira Nusantara   Jan 3, 2026
# 122609  3680350                     A Lenda de Niterói   Jan 4, 2026
# 122610  4141790                          [BEAT:KEEPER]   Jan 5, 2026
#
#        required_age price dlc_count  \
# 0                 0   0.0         0
# 1                 0  5.24         0
# ...

# %%
raw_json = raw_json.reset_index()
raw = raw_json.rename(columns= {"index": "appID"})
raw.columns
# Out:
# Index(['level_0', 'appID', 'name', 'release_date', 'required_age', 'price',
#        'dlc_count', 'detailed_description', 'about_the_game',
#        'short_description', 'reviews', 'header_image', 'website',
#        'support_url', 'support_email', 'windows', 'mac', 'linux',
#        'metacritic_score', 'metacritic_url', 'achievements', 'recommendations',
#        'notes', 'supported_languages', 'full_audio_languages', 'packages',
#        'developers', 'publishers', 'categories', 'genres', 'screenshots',
#        'movies', 'user_score', 'score_rank', 'positive', 'negative',
#        'estimated_owners', 'average_playtime_forever',
#        'average_playtime_2weeks', 'median_playtime_forever',
#        'median_playtime_2weeks', 'discount', 'peak_ccu', 'tags'],
#       dtype='str')

# %%
raw = raw[[
    'appID',
    'name',
    'release_date',
    'required_age',
    'price',
    'dlc_count',
    'reviews',
    'metacritic_score',
    'achievements',
    'recommendations',
    'supported_languages',
    'full_audio_languages',
    'developers',
    'publishers',
    'categories',
    'genres',
    'user_score',
    'score_rank',
    'positive',
    'negative',
    'estimated_owners',
    'average_playtime_forever',
    'average_playtime_2weeks',
    'peak_ccu',
    'tags'
]]

raw.to_csv('..\\data\\processed\\data.csv',index=False)
